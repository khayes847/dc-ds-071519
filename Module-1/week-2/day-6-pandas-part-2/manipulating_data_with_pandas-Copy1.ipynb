# %% [markdown]
# # Module 1 - Manipulating data with Pandas
# ## Pandas Part 2

# %% [markdown]
# ![austin](http://www.austintexas.gov/sites/default/files/aac_logo.jpg)
#
# ## Scenario:
# You have decided that you want to start your own animal shelter, but you want to get an idea of what that will entail and get more information about planning. In this lecture, we are continue to look at a real data set collected by Austin Animal Center over several years and use our pandas skills from the last lecture and learn some new ones in order to explore this data further.
#
# #### _Our goals today are to be able to_: <br/>
#
# Use the pandas library to:
#
# - Get summary info about a dataset and its variables
#   - Apply and use info, describe and dtypes
#   - Use mean, min, max, and value_counts
# - Use apply and applymap to transform columns and create new values
#
# - Explain lambda functions and use them to use an apply on a DataFrame
# - Explain what a groupby object is and split a DataFrame using a groupby
# - Reshape a DataFrame using joins, merges, pivoting, stacking, and melting

# %% [markdown]
# ## Getting started
#
# Let's take a moment to examine the [Austin Animal Center data set](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Outcomes/9t4d-g238/data). What kinds of questions can we ask this data and what kinds of information can we get back?
#
# In pairs and as a class, let's generate ideas.
#
# ## Switch gears
#
# Before we answer those questions about the animal shelter data, let's practice on a simpler dataset.
# Read about this dataset here: https://www.kaggle.com/ronitf/heart-disease-uci
# ![heart-data](images/heartbloodpres.jpeg)
#
# The dataset is most often used to practice classification algorithms. Can one develop a model to predict the likelihood of heart disease based on other measurable characteristics? We will return to that specific question in a few weeks, but for now we wish to use the dataset to practice some pandas methods.

# %% [markdown]
# ### 1. Get summary info about a dataset and its variables
#
# Applying and using `info`, `describe`, `mean`, `min`, `max`, `apply`, and `applymap` from the Pandas library

# %% [markdown]
# The Pandas library has several useful tools built in. Let's explore some of them.

# %%
# !pwd # check location. chdir = change directory
# !ls -al
# Out:
# /c/Users/Rocio/Desktop/Class_files/dc-ds-071519/Module-1/week-2/day-6-pandas-part-2
# pwd: ignoring non-option arguments
# total 417
# drwxr-xr-x 1 Rocio 197609      0 Jul 23 12:32 .
# drwxr-xr-x 1 Rocio 197609      0 Jul 23 12:13 ..
# drwxr-xr-x 1 Rocio 197609      0 Jul 23 12:32 .ipynb_checkpoints
# -rw-r--r-- 1 Rocio 197609  11325 Jul 23 12:13 heart.csv
# -rw-r--r-- 1 Rocio 197609  18136 Jul 23 12:13 manipulating_data_with_pandas.ipynb
# -rw-r--r-- 1 Rocio 197609 196047 Jul 23 12:13 manipulating_data_with_pandas_sol.ipynb
# -rw-r--r-- 1 Rocio 197609 188157 Jul 23 12:13 manipulating_data_with_pandas-Copy1.ipynb
# -rw-r--r-- 1 Rocio 197609   3356 Jul 23 12:13 pre_process_animal_shelter_data.py
# -rw-r--r-- 1 Rocio 197609    136 Jul 23 12:13 states.csv

# %%
import pandas as pd
uci = pd.read_csv('heart.csv')

# %%
uci.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0    2.300      0
# 1   37    1   2       130   250    0        1      187      0    3.500      0
# 2   41    0   1       130   204    0        0      172      0    1.400      2
# 3   56    1   1       120   236    0        1      178      0    0.800      2
# 4   57    0   0       120   354    0        1      163      1    0.600      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# #### The `.columns` and `.shape` Attributes

# %%
uci.columns

# %%
uci.shape

# %% [markdown]
# #### The `.info() `and `.describe()` and `.dtypes` methods

# %% [markdown]
# Pandas DataFrames have many useful methods! Let's look at `.info()` , `.describe()`, and `dtypes`.

# %%
# Call the .info() method on our dataset. What do you observe?

uci.info()

# %%
# Call the .describe() method on our dataset. What do you observe?

#uci.describe()
uci.describe().T # .T = Transpose output

# %%
# Use the code below. How does the output differ from info() ?
uci.dtypes # ONLY SHOWS NUMERIC, NOT CATEGORICAL

# %%
type(uci.age)

# %% [markdown]
# #### `.mean()`, .`min()`,` .max()`, `.sum()`

# %% [markdown]
# The methods `.mean()`, `.min()`, and `.max()` will perform just the way you think they will!
#
# Note that these are methods both for Series and for DataFrames.

# %%
uci.ca.mean()

# %% [markdown]
# #### The Axis Variable

# %%
uci.sum() # Try [shift] + [tab] here!

# %%
uci.mean()

# %% [markdown]
# #### .`value_counts()`

# %% [markdown]
# For a DataFrame _Series_, the `.value_counts()` method will tell you how many of each value you've got.

# %%
uci['age'].value_counts()[:10] #Top ten, sorted by value

# %% [markdown]
# Exercise: What are the different values for restecg?

# %%
uci['restecg'].value_counts()

# %% [markdown]
# ### Apply to Animal Shelter Data
# Using `.info()` and `.describe()` and `dtypes` what observations can we make about the data?
#
# What are the breed value counts?
#
# How about age counts for dogs?

# %%
animal_outcomes = pd.read_csv('https://data.austintexas.gov/api/views/9t4d-g238/rows.csv?accessType=DOWNLOAD')

# %%
animal_outcomes.describe()
# Out:
#          age_in_days      age_years           year          month
# count  104492.000000  104492.000000  104492.000000  104492.000000
# mean      811.304119       2.222751    2016.132211       6.595328
# std      1077.076051       2.950893       1.730878       3.315509
# min      -376.000000      -1.030137    2013.000000       1.000000
# 25%        95.000000       0.260274    2015.000000       4.000000
# 50%       371.000000       1.016438    2016.000000       7.000000
# 75%      1028.000000       2.816438    2018.000000       9.000000
# max      9137.000000      25.032877    2019.000000      12.000000

# %%
animal_outcomes['Animal Type'].value_counts()
# Out:
# Dog          59507
# Cat          38974
# Other         5517
# Bird           478
# Livestock       16
# Name: Animal Type, dtype: int64

# %%
animal_outcomes.head()
# Out:
#   Animal ID   Name                DateTime               MonthYear  \
# 0   A800396    NaN  07/22/2019 09:01:00 AM  07/22/2019 09:01:00 AM
# 1   A800130  Kolby  07/21/2019 10:56:00 PM  07/21/2019 10:56:00 PM
# 2   A799457  Hazel  07/21/2019 10:55:00 PM  07/21/2019 10:55:00 PM
# 3   A800069    NaN  07/21/2019 07:57:00 PM  07/21/2019 07:57:00 PM
# 4   A795483  *Herb  07/21/2019 07:15:00 PM  07/21/2019 07:15:00 PM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    07/20/2017   Euthanasia     Rabies Risk       Other          Unknown
# 1    05/01/2019     Adoption             NaN         Dog    Spayed Female
# 2    07/08/2013          NaN             NaN         Dog    Spayed Female
# 3    06/02/2019     Transfer         Partner         Cat      Intact Male
# 4    04/21/2019     Adoption             NaN         Cat    Neutered Male
#
#   Age upon Outcome               Breed               Color date_outcome  \
# 0          2 years             Raccoon                Gray   2019-07-22
# 1         2 months               Boxer               Brown   2019-07-21
# 2          6 years            Pit Bull           Tan/White   2019-07-21
# 3          1 month  Domestic Shorthair        Orange Tabby   2019-07-21
# 4         2 months  Domestic Shorthair  Orange Tabby/White   2019-07-21
#
#          dob       age
# 0 2017-07-20  732 days
# 1 2019-05-01   81 days
# 2 2013-07-08 2204 days
# 3 2019-06-02   49 days
# 4 2019-04-21   91 days

# %%
animal_outcomes.Breed.value_counts()
# Out:
# Domestic Shorthair Mix                         29921
# Pit Bull Mix                                    7934
# Labrador Retriever Mix                          6181
# Chihuahua Shorthair Mix                         5984
# Domestic Medium Hair Mix                        3018
# German Shepherd Mix                             2685
# Bat Mix                                         1741
# Domestic Shorthair                              1689
# Domestic Longhair Mix                           1487
# Australian Cattle Dog Mix                       1345
# Siamese Mix                                     1202
# Bat                                              990
# Dachshund Mix                                    973
# Boxer Mix                                        876
# Border Collie Mix                                855
# Miniature Poodle Mix                             799
# Siberian Husky Mix                               611
# Catahoula Mix                                    608
# Australian Shepherd Mix                          605
# Staffordshire Mix                                605
# Rat Terrier Mix                                  589
# Yorkshire Terrier Mix                            586
# Raccoon Mix                                      535
# Beagle Mix                                       523
# Great Pyrenees Mix                               520
# Jack Russell Terrier Mix                         519
# Miniature Schnauzer Mix                          519
# Chihuahua Longhair Mix                           470
# Cairn Terrier Mix                                461
# Pointer Mix                                      455
#                                                ...
# Great Dane/Pointer                                 1
# Beagle/German Shorthair Pointer                    1
# Finnish Spitz/Dachshund                            1
# Cardigan Welsh Corgi/Cardigan Welsh Corgi          1
# Miniature Pinscher/Pomeranian                      1
# Ibizan Hound/Pit Bull                              1
# Australian Shepherd/Dalmatian                      1
# Italian Greyhound/Cavalier Span                    1
# Labrador Retriever/Chihuahua Shorthair             1
# Jack Russell Terrier/Papillon                      1
# American Bulldog/Blue Lacy                         1
# Great Pyrenees/Rat Terrier                         1
# Treeing Walker Coonhound/Dachshund                 1
# Vizsla/Boxer                                       1
# Jindo/Labrador Retriever                           1
# Japanese Bobtail/American Curl Shorthair           1
# Pug/Pit Bull                                       1
# English Springer Spaniel/Labrador Retriever        1
# Polish Mix                                         1
# Whippet/Jack Russell Terrier                       1
# Cavalier Span/Pug                                  1
# Belgian Hare                                       1
# Australian Cattle Dog/Basset Hound                 1
# Border Terrier/Affenpinscher                       1
# Pharaoh Hound/Australian Cattle Dog                1
# Chihuahua Longhair/Cavalier Span                   1
# Border Collie/Canaan Dog                           1
# German Shepherd/Finnish Spitz                      1
# Golden Retriever/Pit Bull                          1
# Norfolk Terrier/Dachshund Wirehair                 1
# Name: Breed, Length: 2434, dtype: int64

# %%
animal_outcomes[animal_outcomes['Animal Type'] == "Dog"].Breed.value_counts()
# Out:
# Pit Bull Mix                                         7934
# Labrador Retriever Mix                               6181
# Chihuahua Shorthair Mix                              5984
# German Shepherd Mix                                  2685
# Australian Cattle Dog Mix                            1345
# Dachshund Mix                                         973
# Boxer Mix                                             876
# Border Collie Mix                                     855
# Miniature Poodle Mix                                  799
# Siberian Husky Mix                                    611
# Catahoula Mix                                         608
# Staffordshire Mix                                     605
# Australian Shepherd Mix                               605
# Rat Terrier Mix                                       589
# Yorkshire Terrier Mix                                 586
# Beagle Mix                                            523
# Great Pyrenees Mix                                    520
# Miniature Schnauzer Mix                               519
# Jack Russell Terrier Mix                              519
# Chihuahua Longhair Mix                                470
# Cairn Terrier Mix                                     461
# Pointer Mix                                           455
# Labrador Retriever                                    430
# German Shepherd                                       425
# Rottweiler Mix                                        412
# Pit Bull                                              410
# American Bulldog Mix                                  408
# Chihuahua Shorthair                                   389
# Shih Tzu Mix                                          380
# Anatol Shepherd Mix                                   374
#                                                      ...
# German Shepherd/Basenji                                 1
# Coton De Tulear                                         1
# Alaskan Husky/Chow Chow                                 1
# Miniature Schnauzer/Border Terrier                      1
# German Shepherd/Weimaraner                              1
# Standard Schnauzer/Soft Coated Wheaten Terrier          1
# Akita/Chow Chow                                         1
# Rat Terrier/Lhasa Apso                                  1
# Treeing Walker Coonhound/German Shorthair Pointer       1
# Dachshund/Italian Greyhound                             1
# Bull Terrier/Jack Russell Terrier                       1
# Beagle/Cairn Terrier                                    1
# Collie Smooth/Beagle                                    1
# Flat Coat Retriever/Australian Cattle Dog               1
# Beagle/Mastiff                                          1
# American Pit Bull Terrier/American Bulldog              1
# Dalmatian/Boxer                                         1
# Pbgv/Pit Bull                                           1
# Swedish Vallhund/Miniature Poodle                       1
# Chow Chow/Irish Setter                                  1
# Cavalier Span/Chihuahua Longhair                        1
# Boxer/Jack Russell Terrier                              1
# Miniature Poodle/Cavalier Span                          1
# Redbone Hound/Australian Cattle Dog                     1
# Bull Terrier/Australian Kelpie                          1
# Manchester Terrier/Chihuahua Longhair                   1
# French Bulldog/English Bulldog                          1
# St. Bernard Rough Coat/Labrador Retriever               1
# Chihuahua Longhair/Border Terrier                       1
# Australian Shepherd/Unknown                             1
# Name: Breed, Length: 2158, dtype: int64

# %%
animal_outcomes[(animal_outcomes['Animal Type'] == "Dog") & (animal_outcomes['Outcome Type'] == "Adoption")].Breed.value_counts()

# %% [markdown]
# What are the breed `value_counts`?
# What's the top breed for adopted dogs?
#
# How about outcome counts for dogs?

# %% [markdown]
# ### 2.  Changing data
#
# #### DataFrame.applymap() and Series.map()

# %% [markdown]
# The ```.applymap()``` method takes a function as input that it will then apply to every entry in the dataframe.

# %%
def successor(x):
    return x + 1

# %%
uci.head(1)

# %%
uci.applymap(successor).head()

# %% [markdown]
# The `.map()` method takes a function as input that it will then apply to every entry in the Series.

# %%
uci['age'].map(successor).tail(10)

# %% [markdown]
# #### Anonymous Functions (Lambda Abstraction)

# %% [markdown]
# Simple functions can be defined right in the function call. This is called 'lambda abstraction'; the function thus defined has no name and hence is "anonymous".

# %%
uci['oldpeak'].map(lambda x: round(x))[:4]

# %% [markdown]
# Exercise: Use an anonymous function to turn the entries in age to strings

# %%
uci.age.map(lambda x: str(x)).head(2)

# %% [markdown]
# ### Apply to Animal Shelter Data
#
# Use an `apply` to change the dates from strings to datetime objects. Similarly, use an apply to change the ages of the animals from strings to floats.

# %%
# Your code here

# %%
animal_outcomes.DateTime.dtype
# Out:
# dtype('O')

# %%
animal_outcomes["date_outcome"] = animal_outcomes.DateTime.map(lambda x : pd.to_datetime(x[:10], format = '%m/%d/%Y'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d12acbd868a6> in <module>
# ----> 1 animal_outcomes["date_outcome"] = animal_outcomes.DateTime.map(lambda x : pd.to_datetime(x[:10], format = '%m/%d/%Y'))
#
# NameError: name 'animal_outcomes' is not defined

# %%
animal_outcomes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104443 entries, 0 to 104442
# Data columns (total 15 columns):
# Animal ID           104443 non-null object
# Name                71690 non-null object
# DateTime            104443 non-null object
# MonthYear           104443 non-null object
# Date of Birth       104443 non-null object
# Outcome Type        104436 non-null object
# Outcome Subtype     47572 non-null object
# Animal Type         104443 non-null object
# Sex upon Outcome    104441 non-null object
# Age upon Outcome    104429 non-null object
# Breed               104443 non-null object
# Color               104443 non-null object
# date_outcome        104443 non-null datetime64[ns]
# dob                 104443 non-null datetime64[ns]
# age                 104443 non-null timedelta64[ns]
# dtypes: datetime64[ns](2), object(12), timedelta64[ns](1)
# memory usage: 12.0+ MB

# %%
animal_outcomes.head()
# Out:
#   Animal ID   Name                DateTime               MonthYear  \
# 0   A800396    NaN  07/22/2019 09:01:00 AM  07/22/2019 09:01:00 AM
# 1   A800130  Kolby  07/21/2019 10:56:00 PM  07/21/2019 10:56:00 PM
# 2   A799457  Hazel  07/21/2019 10:55:00 PM  07/21/2019 10:55:00 PM
# 3   A800069    NaN  07/21/2019 07:57:00 PM  07/21/2019 07:57:00 PM
# 4   A795483  *Herb  07/21/2019 07:15:00 PM  07/21/2019 07:15:00 PM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    07/20/2017   Euthanasia     Rabies Risk       Other          Unknown
# 1    05/01/2019     Adoption             NaN         Dog    Spayed Female
# 2    07/08/2013          NaN             NaN         Dog    Spayed Female
# 3    06/02/2019     Transfer         Partner         Cat      Intact Male
# 4    04/21/2019     Adoption             NaN         Cat    Neutered Male
#
#   Age upon Outcome               Breed               Color date_outcome  \
# 0          2 years             Raccoon                Gray   2019-07-22
# 1         2 months               Boxer               Brown   2019-07-21
# 2          6 years            Pit Bull           Tan/White   2019-07-21
# 3          1 month  Domestic Shorthair        Orange Tabby   2019-07-21
# 4         2 months  Domestic Shorthair  Orange Tabby/White   2019-07-21
#
#          dob       age
# 0 2017-07-20  732 days
# 1 2019-05-01   81 days
# 2 2013-07-08 2204 days
# 3 2019-06-02   49 days
# 4 2019-04-21   91 days

# %%
animal_outcomes['Age upon Outcome']
# Out:
# 0           1 month
# 1          3 months
# 2            1 year
# 3          2 months
# 4           2 years
# 5           9 years
# 6           6 years
# 7          10 years
# 8          3 months
# 9          8 months
# 10         3 months
# 11         3 months
# 12        11 months
# 13         3 months
# 14         4 months
# 15          3 years
# 16          2 years
# 17         4 months
# 18           1 year
# 19         5 months
# 20         4 months
# 21         2 months
# 22         3 months
# 23         2 months
# 24         6 months
# 25          9 years
# 26          5 years
# 27         4 months
# 28         3 months
# 29          2 years
#             ...
# 104461      3 years
# 104462     14 years
# 104463      2 years
# 104464     14 years
# 104465     9 months
# 104466     10 years
# 104467      3 weeks
# 104468      3 weeks
# 104469      1 weeks
# 104470      1 weeks
# 104471       1 week
# 104472     4 months
# 104473      1 month
# 104474      3 years
# 104475      7 years
# 104476       1 year
# 104477      2 years
# 104478      3 years
# 104479       1 year
# 104480     5 months
# 104481     6 months
# 104482      9 years
# 104483      3 years
# 104484      2 years
# 104485      3 years
# 104486      4 years
# 104487       1 week
# 104488       1 week
# 104489       1 week
# 104490     2 months
# Name: Age upon Outcome, Length: 104491, dtype: object

# %%
animal_outcomes["dob"] = animal_outcomes\
['Date of Birth'].map(lambda x : pd.to_datetime(x, format = '%m/%d/%Y'))

# %%
animal_outcomes['age_days'] = (animal_outcomes.date_outcome - animal_outcomes.dob).dt.days

# %%
animal_outcomes['age_years'] = animal_outcomes['age_days']/365

# %%
animal_outcomes.head()
# Out:
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A798909      NaN  07/22/2019 09:34:00 PM  07/22/2019 09:34:00 PM
# 1   A798933      NaN  07/22/2019 09:33:00 PM  07/22/2019 09:33:00 PM
# 2   A800552      NaN  07/22/2019 07:34:00 PM  07/22/2019 07:34:00 PM
# 3   A799925      NaN  07/22/2019 07:27:00 PM  07/22/2019 07:27:00 PM
# 4   A800293  Brixton  07/22/2019 07:26:00 PM  07/22/2019 07:26:00 PM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    06/02/2019     Adoption             NaN         Cat    Spayed Female
# 1    04/17/2019     Adoption             NaN         Cat    Neutered Male
# 2    07/22/2018   Euthanasia     Rabies Risk       Other          Unknown
# 3    05/01/2019     Adoption             NaN         Dog    Neutered Male
# 4    07/18/2017     Adoption             NaN         Dog    Neutered Male
#
#   Age upon Outcome                               Breed             Color  \
# 0          1 month                  Domestic Shorthair             Black
# 1         3 months                  Domestic Shorthair  Blue Tabby/White
# 2           1 year                                 Bat             Brown
# 3         2 months  Labrador Retriever/German Shepherd             Black
# 4          2 years                            Pit Bull       Brown/White
#
#    year date_outcome        dob  month      age  age_in_days  age_years
# 0  2019   2019-07-22 2019-06-02      7  50 days           50   0.136986
# 1  2019   2019-07-22 2019-04-17      7  96 days           96   0.263014
# 2  2019   2019-07-22 2018-07-22      7 365 days          365   1.000000
# 3  2019   2019-07-22 2019-05-01      7  82 days           82   0.224658
# 4  2019   2019-07-22 2017-07-18      7 734 days          734   2.010959

# %%
animal_outcomes.DateTime.data()
# Out:
# C:\Users\Rocio\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Series.data is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-2baae9bf0629> in <module>
# ----> 1 animal_outcomes.DateTime.data()
#
# TypeError: 'memoryview' object is not callable

# %%
# Dont use
animal_outcomes['age'] = ((animal_outcomes['age'].astype('int64')/86400000000000)) ## Change timedelta64 to int64

# %%
animal_outcomes.head(1)
# Out:
#   Animal ID    Name                DateTime               MonthYear  \
# 0   A798405  *Benny  07/22/2019 10:38:00 AM  07/22/2019 10:38:00 AM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    06/25/2018     Adoption             NaN         Cat    Neutered Male
#
#   Age upon Outcome               Breed        Color date_outcome        dob  \
# 0           1 year  Domestic Shorthair  Black/White   2019-07-22 2018-06-25
#
#       age
# 0 392.000

# %% [markdown]
# ## 3. Methods for Re-Organizing DataFrames
# #### `.groupby()`

# %% [markdown]
# Those of you familiar with SQL have probably used the GROUP BY command. Pandas has this, too.
#
# The `.groupby()` method is especially useful for aggregate functions applied to the data grouped in particular ways.

# %%
uci.groupby('sex')

# %% [markdown]
# #### `.groups` and `.get_group()`

# %%
uci.groupby('sex').groups #Two groups are 0 and 1
# Out:
# {0: Int64Index([  2,   4,   6,  11,  14,  15,  16,  17,  19,  25,  28,  30,  35,
#               36,  38,  39,  40,  43,  48,  49,  50,  53,  54,  59,  60,  65,
#               67,  69,  74,  75,  82,  84,  85,  88,  89,  93,  94,  96, 102,
#              105, 107, 108, 109, 110, 112, 115, 118, 119, 120, 122, 123, 124,
#              125, 127, 128, 129, 130, 131, 134, 135, 136, 140, 142, 143, 144,
#              146, 147, 151, 153, 154, 155, 161, 167, 181, 182, 190, 204, 207,
#              213, 215, 216, 220, 223, 241, 246, 252, 258, 260, 263, 266, 278,
#              289, 292, 296, 298, 302],
#             dtype='int64'),
#  1: Int64Index([  0,   1,   3,   5,   7,   8,   9,  10,  12,  13,
#              ...
#              288, 290, 291, 293, 294, 295, 297, 299, 300, 301],
#             dtype='int64', length=207)}

# %%
uci.groupby('sex').get_group(0) # .tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 2     41    0   1       130   204    0        0      172      0      1.4
# 4     57    0   0       120   354    0        1      163      1      0.6
# 6     56    0   1       140   294    0        0      153      0      1.3
# 11    48    0   2       130   275    0        1      139      0      0.2
# 14    58    0   3       150   283    1        0      162      0      1.0
# 15    50    0   2       120   219    0        1      158      0      1.6
# 16    58    0   2       120   340    0        1      172      0      0.0
# 17    66    0   3       150   226    0        1      114      0      2.6
# 19    69    0   3       140   239    0        1      151      0      1.8
# 25    71    0   1       160   302    0        1      162      0      0.4
# 28    65    0   2       140   417    1        0      157      0      0.8
# 30    41    0   1       105   198    0        1      168      0      0.0
# 35    46    0   2       142   177    0        0      160      1      1.4
# 36    54    0   2       135   304    1        1      170      0      0.0
# 38    65    0   2       155   269    0        1      148      0      0.8
# 39    65    0   2       160   360    0        0      151      0      0.8
# 40    51    0   2       140   308    0        0      142      0      1.5
# 43    53    0   0       130   264    0        0      143      0      0.4
# 48    53    0   2       128   216    0        0      115      0      0.0
# 49    53    0   0       138   234    0        0      160      0      0.0
# 50    51    0   2       130   256    0        0      149      0      0.5
# 53    44    0   2       108   141    0        1      175      0      0.6
# 54    63    0   2       135   252    0        0      172      0      0.0
# 59    57    0   0       128   303    0        0      159      0      0.0
# 60    71    0   2       110   265    1        0      130      0      0.0
# 65    35    0   0       138   183    0        1      182      0      1.4
# 67    45    0   1       130   234    0        0      175      0      0.6
# 69    62    0   0       124   209    0        1      163      0      0.0
# 74    43    0   2       122   213    0        1      165      0      0.2
# 75    55    0   1       135   250    0        0      161      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 147   60    0   3       150   240    0        1      171      0      0.9
# 151   71    0   0       112   149    0        1      125      0      1.6
# 153   66    0   2       146   278    0        0      152      0      0.0
# 154   39    0   2       138   220    0        1      152      0      0.0
# 155   58    0   0       130   197    0        1      131      0      0.6
# 161   55    0   1       132   342    0        1      166      0      1.2
# 167   62    0   0       140   268    0        0      160      0      3.6
# 181   65    0   0       150   225    0        0      114      0      1.0
# 182   61    0   0       130   330    0        0      169      0      0.0
# 190   51    0   0       130   305    0        1      142      1      1.2
# 204   62    0   0       160   164    0        0      145      0      6.2
# 207   60    0   0       150   258    0        0      157      0      2.6
# 213   61    0   0       145   307    0        0      146      1      1.0
# 215   43    0   0       132   341    1        0      136      1      3.0
# 216   62    0   2       130   263    0        1       97      0      1.2
# 220   63    0   0       150   407    0        0      154      0      4.0
# 223   56    0   0       200   288    1        0      133      1      4.0
# 241   59    0   0       174   249    0        1      143      1      0.0
# 246   56    0   0       134   409    0        0      150      1      1.9
# 252   62    0   0       138   294    1        1      106      0      1.9
# 258   62    0   0       150   244    0        1      154      1      1.4
# 260   66    0   0       178   228    1        1      165      1      1.0
# 263   63    0   0       108   269    0        1      169      1      1.8
# 266   55    0   0       180   327    0        2      117      1      3.4
# 278   58    0   1       136   319    1        0      152      0      0.0
# 289   55    0   0       128   205    0        2      130      1      2.0
# 292   58    0   0       170   225    1        0      146      1      2.8
# 296   63    0   0       124   197    0        1      136      1      0.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 2        2   0     2       1
# 4        2   0     2       1
# 6        1   0     2       1
# 11       2   0     2       1
# 14       2   0     2       1
# 15       1   0     2       1
# 16       2   0     2       1
# 17       0   0     2       1
# 19       2   2     2       1
# 25       2   2     2       1
# 28       2   1     2       1
# 30       2   1     2       1
# 35       0   0     2       1
# 36       2   0     2       1
# 38       2   0     2       1
# 39       2   0     2       1
# 40       2   1     2       1
# 43       1   0     2       1
# 48       2   0     0       1
# 49       2   0     2       1
# 50       2   0     2       1
# 53       1   0     2       1
# 54       2   0     2       1
# 59       2   1     2       1
# 60       2   1     2       1
# 65       2   0     2       1
# 67       1   0     2       1
# 69       2   0     2       1
# 74       1   0     2       1
# 75       1   0     2       1
# ..     ...  ..   ...     ...
# 147      2   0     2       1
# 151      1   0     2       1
# 153      1   1     2       1
# 154      1   0     2       1
# 155      1   0     2       1
# 161      2   0     2       1
# 167      0   2     2       0
# 181      1   3     3       0
# 182      2   0     2       0
# 190      1   0     3       0
# 204      0   3     3       0
# 207      1   2     3       0
# 213      1   0     3       0
# 215      1   0     3       0
# 216      1   1     3       0
# 220      1   3     3       0
# 223      0   2     3       0
# 241      1   0     2       0
# 246      1   2     3       0
# 252      1   3     2       0
# 258      1   0     2       0
# 260      1   2     3       0
# 263      1   2     2       0
# 266      1   0     2       0
# 278      2   2     2       0
# 289      1   1     3       0
# 292      1   2     1       0
# 296      1   0     2       0
# 298      1   0     3       0
# 302      1   1     2       0
#
# [96 rows x 14 columns]

# %% [markdown]
# ### Aggregating

# %%
uci.groupby('sex').std()
# Out:
#           age        cp   trestbps       chol       fbs   restecg    thalach  \
# sex
# 0    9.409396  0.972427  19.311119  65.088946  0.332455  0.557150  20.047969
# 1    8.883803  1.059064  16.658246  42.782392  0.366955  0.510754  24.130882
#
#         exang   oldpeak     slope        ca      thal    target
# sex
# 0    0.422503  1.119844  0.593736  0.881026  0.441290  0.435286
# 1    0.484505  1.174632  0.627378  1.074082  0.659949  0.498626

# %% [markdown]
# Exercise: Tell me the average cholesterol level for those with heart disease.

# %%
# Your code here!

# %% [markdown]
# ### Apply to Animal Shelter Data
#
# #### Task 1
# - Use a groupby to show the average age of the different kinds of animal types.
# - What about by animal types **and** gender?

# %%
animal_outcomes.groupby(['Animal Type', 'Sex upon Outcome']).mean()
# Out:
#                                   age
# Animal Type Sex upon Outcome
# Bird        Intact Female     824.400
#             Intact Male       564.667
#             Unknown           406.365
# Cat         Intact Female     335.600
#             Intact Male       229.874
#             Neutered Male     722.122
#             Spayed Female     737.802
#             Unknown           186.856
# Dog         Intact Female     838.046
#             Intact Male       902.391
#             Neutered Male    1086.293
#             Spayed Female    1050.244
#             Unknown           403.109
# Livestock   Intact Female     434.500
#             Intact Male       631.400
#             Neutered Male     376.000
#             Unknown           143.750
# Other       Intact Female     585.947
#             Intact Male       550.567
#             Neutered Male     577.122
#             Spayed Female     566.622
#             Unknown           445.299

# %%
animal_outcomes.groupby('Animal Type')['age'].mean()
# Out:
# Animal Type
# Bird         511.893
# Cat          539.721
# Dog         1023.865
# Livestock    419.688
# Other        463.718
# Name: age, dtype: float64

# %%
animal_outcomes.groupby(['Animal Type', 'Sex upon Outcome']).mean()
# Out:
#                                   age
# Animal Type Sex upon Outcome
# Bird        Intact Female     824.400
#             Intact Male       564.667
#             Unknown           406.365
# Cat         Intact Female     335.600
#             Intact Male       229.874
#             Neutered Male     722.122
#             Spayed Female     737.802
#             Unknown           186.856
# Dog         Intact Female     838.046
#             Intact Male       902.391
#             Neutered Male    1086.293
#             Spayed Female    1050.244
#             Unknown           403.109
# Livestock   Intact Female     434.500
#             Intact Male       631.400
#             Neutered Male     376.000
#             Unknown           143.750
# Other       Intact Female     585.947
#             Intact Male       550.567
#             Neutered Male     577.122
#             Spayed Female     566.622
#             Unknown           445.299

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x) # remove scientific thing

# %% [markdown]
# #### Task 2:
# - Create new columns `year` and `month` by using a lambda function x.year on date
# - Use `groupby` and `.size()` to tell me how many animals are adopted by month

# %%
animal_outcomes.head()
# Out:
#   Animal ID    Name                DateTime               MonthYear  \
# 0   A798405  *Benny  07/22/2019 10:38:00 AM  07/22/2019 10:38:00 AM
# 1   A800396     NaN  07/22/2019 09:01:00 AM  07/22/2019 09:01:00 AM
# 2   A800130   Kolby  07/21/2019 10:56:00 PM  07/21/2019 10:56:00 PM
# 3   A799457   Hazel  07/21/2019 10:55:00 PM  07/21/2019 10:55:00 PM
# 4   A800069     NaN  07/21/2019 07:57:00 PM  07/21/2019 07:57:00 PM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    06/25/2018     Adoption             NaN         Cat    Neutered Male
# 1    07/20/2017   Euthanasia     Rabies Risk       Other          Unknown
# 2    05/01/2019     Adoption             NaN         Dog    Spayed Female
# 3    07/08/2013          NaN             NaN         Dog    Spayed Female
# 4    06/02/2019     Transfer         Partner         Cat      Intact Male
#
#   Age upon Outcome               Breed         Color date_outcome        dob  \
# 0           1 year  Domestic Shorthair   Black/White   2019-07-22 2018-06-25
# 1          2 years             Raccoon          Gray   2019-07-22 2017-07-20
# 2         2 months               Boxer         Brown   2019-07-21 2019-05-01
# 3          6 years            Pit Bull     Tan/White   2019-07-21 2013-07-08
# 4          1 month  Domestic Shorthair  Orange Tabby   2019-07-21 2019-06-02
#
#        age  year  month
# 0  392.000  2019      7
# 1  732.000  2019      7
# 2   81.000  2019      7
# 3 2204.000  2019      7
# 4   49.000  2019      7

# %%
animal_outcomes["year"] = animal_outcomes.DateTime.map

# %%
animal_outcomes["year"] = animal_outcomes.date_outcome.map(lambda x : x.year)

# %%
animal_outcomes["month"] = animal_outcomes.date_outcome.map(lambda x : x.month)

# %%
animal_outcomes[animal_outcomes['Outcome Type'] == 'Adoption']\
.groupby(['year','month']).size()
# Out:
# year  month
# 2013  10        606
#       11        552
#       12        684
# 2014  1         518
#       2         437
#       3         483
#       4         439
#       5         507
#       6         660
#       7         907
#       8         816
#       9         607
#       10        582
#       11        519
#       12        652
# 2015  1         540
#       2         484
#       3         472
#       4         402
#       5         629
#       6         706
#       7         896
#       8         721
#       9         630
#       10        583
#       11        658
#       12        656
# 2016  1         599
#       2         539
#       3         540
#                ...
# 2017  2         647
#       3         440
#       4         510
#       5         702
#       6         746
#       7         867
#       8         851
#       9         686
#       10        709
#       11        575
#       12        649
# 2018  1         572
#       2         508
#       3         592
#       4         471
#       5         620
#       6         790
#       7         808
#       8         914
#       9         665
#       10        698
#       11        482
#       12        803
# 2019  1         757
#       2         554
#       3         664
#       4         531
#       5         716
#       6        1019
#       7         638
# Length: 70, dtype: int64

# %%
animal_outcomes.groupby(['Animal Type'])['age_days'].mean()
# Out:
# Animal Type
# Bird          511.893305
# Cat           539.390612
# Dog          1024.058715
# Livestock     419.687500
# Other         463.700381
# Name: age_days, dtype: float64

# %%
animal_outcomes.groupby(['Animal Type'])['age_years'].mean()
# Out:
# Animal Type
# Bird         1.402447
# Cat          1.477782
# Dog          2.805640
# Livestock    1.149829
# Other        1.270412
# Name: age_years, dtype: float64

# %% [markdown]
# ## 4. Reshaping a DataFrame
#
# ### `.pivot()`

# %% [markdown]
# Those of you familiar with Excel have probably used Pivot Tables. Pandas has a similar functionality.

# %%
uci.pivot(values = 'sex', columns = 'target').head()
# Out:
# target   0     1
# 0      nan 1.000
# 1      nan 1.000
# 2      nan 0.000
# 3      nan 1.000
# 4      nan 0.000

# %%
animal_outcomes.pivot_table(values = 'age_years', index ='Animal Type', columns = 'Outcome Type')
# Set rows by index, values by values, and columns by columns
# Out:
# Outcome Type  Adoption      Died  Disposal  Euthanasia   Missing  Relocate  \
# Animal Type
# Bird          1.436348  1.207828  1.003767    1.315504  1.052055  2.882496
# Cat           1.308130  1.194283  2.043955    3.209395  1.385898       NaN
# Dog           2.083231  2.819843  2.448532    4.684750  2.285985       NaN
# Livestock     1.089954  0.041096       NaN         NaN       NaN       NaN
# Other         1.360477  0.999807  1.144907    1.309469  0.564384  0.832055
#
# Outcome Type  Return to Owner  Rto-Adopt  Transfer
# Animal Type
# Bird                 1.290250        NaN  1.437576
# Cat                  4.339341   3.653078  1.164983
# Dog                  4.109438   3.580149  2.380233
# Livestock            0.447489        NaN  1.745662
# Other                2.519048        NaN  1.085887

# %% [markdown]
# ### Methods for Combining DataFrames: `.join()`, `.merge()`, `.concat()`, `.melt()`

# %% [markdown]
# ### `.join()`

# %%
toy1 = pd.DataFrame([[63, 142], [33, 47]], columns = ['age', 'HP'])
toy2 = pd.DataFrame([[63, 100], [33, 200]], columns = ['age', 'HP'])
toy2
# Out:
#    age   HP
# 0   63  100
# 1   33  200

# %%
toy1.join(toy2.set_index('age'),
          on = 'age',
          lsuffix = '_A',
          rsuffix = '_B').head()
#Toy 1 is left data, toy 2 is right data. They join at the 'age' column.
# Out:
#    age  HP_A  HP_B
# 0   63   142   100
# 1   33    47   200

# %% [markdown]
# ### `.merge()`

# %%
ds_chars = pd.read_csv('ds_chars.csv', index_col = 0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-0eb10367a00b> in <module>
# ----> 1 ds_chars = pd.read_csv('ds_chars.csv', index_col = 0)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'ds_chars.csv' does not exist: b'ds_chars.csv'

# %%
states = pd.read_csv('states.csv', index_col = 0)

# %%
ds_chars.merge(states,
               left_on='home_state',
               right_on = 'state',
               how = 'inner')
# Merge defaults to inner, join defaults to left

# %% [markdown]
# ### `pd.concat()`

# %% [markdown]
# Exercise: Look up the documentation on pd.concat (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html) and use it to concatenate ds_chars and states.
# <br/>
# Your result should still have only five rows!

# %%
pd.concat([ds_chars, states])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-af5bf311c762> in <module>
# ----> 1 pd.concat([ds_chars, states])
#
# NameError: name 'ds_chars' is not defined

# %% [markdown]
# ### `pd.melt()`

# %% [markdown]
# Melting removes the structure from your DataFrame and puts the data in a 'variable' and 'value' format.

# %%
ds_chars.head()

# %%
pd.melt(ds_chars,
        id_vars=['name'],
        value_vars=['HP', 'home_state'])

# %% [markdown]
# ## Bringing it all together with the Animal Shelter Data
#
# Join the data from the [Austin Animal Shelter Intake dataset](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm) to the outcomes dataset by Animal ID.
#
# Use the dates from each dataset to see how long animals spend in the shelter. Does it differ by time of year? By outcome?
#
# The Url for the Intake Dataset is here: https://data.austintexas.gov/api/views/wter-evkm/rows.csv?accessType=DOWNLOAD
#
# _Hints_ :
# - import and clean the intake dataset first
# - use apply/applymap/lambda to change the variables to their proper format in the intake data
# - rename the columns in the intake dataset *before* joining
# - create a new days-in-shelter variable
# - Notice that some values in "days_in_shelter" column are NaN or values < 0 (remove these rows using the "<" operator and ~is.na())
# - Use group_by to get some interesting information about the dataset
#
# Make sure to export and save your cleaned dataset. We will use it in a later lecture!
#
# use the notation `df.to_csv()` to write the `df` to a csv. Read more about the `to_csv()` documentation [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html)

# %%
intake_data = pd.read_csv('https://data.austintexas.gov/api/views/wter-evkm/rows.csv?accessType=DOWNLOAD')

# %%
intake_data.head()
# Out:
#   Animal ID   Name                DateTime               MonthYear  \
# 0   A800561    NaN  07/23/2019 08:52:00 AM  07/23/2019 08:52:00 AM
# 1   A800557    NaN  07/23/2019 07:48:00 AM  07/23/2019 07:48:00 AM
# 2   A800556    NaN  07/23/2019 07:20:00 AM  07/23/2019 07:20:00 AM
# 3   A660391    NaN  07/22/2019 06:54:00 PM  07/22/2019 06:54:00 PM
# 4   A739213  Zorro  07/22/2019 06:46:00 PM  07/22/2019 06:46:00 PM
#
#                                   Found Location    Intake Type  \
# 0               11209 Metric Blvd in Austin (TX)          Stray
# 1          1109 S Pleasant Valley in Austin (TX)          Stray
# 2             4434 Frontier Trail in Austin (TX)          Stray
# 3  Pedernales And East 6Th Street in Austin (TX)          Stray
# 4                                     Manor (TX)  Public Assist
#
#   Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0          Injured         Dog   Neutered Male         6 years
# 1           Normal         Cat         Unknown          1 year
# 2          Injured         Cat   Intact Female          1 year
# 3           Normal         Dog     Intact Male         7 years
# 4           Normal         Dog     Intact Male         4 years
#
#                      Breed       Color date_income
# 0   Miniature Pinscher Mix   Black/Tan  2019-07-23
# 1       Domestic Shorthair       Black  2019-07-23
# 2       Domestic Shorthair      Tortie  2019-07-23
# 3             Pit Bull Mix       Brown  2019-07-22
# 4  Australian Shepherd Mix  Black/Gray  2019-07-22

# %%
intake_data["date_intake"] = intake_data.DateTime.map(lambda x : pd.to_datetime(x[:10], format = '%m/%d/%Y'))

# %%
intake_data.head()
# Out:
#   Animal ID   Name                DateTime               MonthYear  \
# 0   A800561    NaN  07/23/2019 08:52:00 AM  07/23/2019 08:52:00 AM
# 1   A800557    NaN  07/23/2019 07:48:00 AM  07/23/2019 07:48:00 AM
# 2   A800556    NaN  07/23/2019 07:20:00 AM  07/23/2019 07:20:00 AM
# 3   A660391    NaN  07/22/2019 06:54:00 PM  07/22/2019 06:54:00 PM
# 4   A739213  Zorro  07/22/2019 06:46:00 PM  07/22/2019 06:46:00 PM
#
#                                   Found Location    Intake Type  \
# 0               11209 Metric Blvd in Austin (TX)          Stray
# 1          1109 S Pleasant Valley in Austin (TX)          Stray
# 2             4434 Frontier Trail in Austin (TX)          Stray
# 3  Pedernales And East 6Th Street in Austin (TX)          Stray
# 4                                     Manor (TX)  Public Assist
#
#   Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0          Injured         Dog   Neutered Male         6 years
# 1           Normal         Cat         Unknown          1 year
# 2          Injured         Cat   Intact Female          1 year
# 3           Normal         Dog     Intact Male         7 years
# 4           Normal         Dog     Intact Male         4 years
#
#                      Breed       Color date_income  year_income  month_income  \
# 0   Miniature Pinscher Mix   Black/Tan  2019-07-23         2019             7
# 1       Domestic Shorthair       Black  2019-07-23         2019             7
# 2       Domestic Shorthair      Tortie  2019-07-23         2019             7
# 3             Pit Bull Mix       Brown  2019-07-22         2019             7
# 4  Australian Shepherd Mix  Black/Gray  2019-07-22         2019             7
#
#    year  month
# 0  2019      7
# 1  2019      7
# 2  2019      7
# 3  2019      7
# 4  2019      7

# %%
intake_data["year"] = intake_data.date_intake.map(lambda x : x.year)

# %%
intake_data["month"] = intake_data.date_intake.map(lambda x : x.month)

# %%
animals_merged = pd.merge(intake_data, animal_outcomes, on=['Animal ID', 'year'], how = 'left', suffixes = ('_intake', '_outcome'))

# %%
animals_merged.head()
# Out:
#   Animal ID Name_intake         DateTime_intake        MonthYear_intake  \
# 0   A800566         NaN  07/23/2019 10:47:00 AM  07/23/2019 10:47:00 AM
# 1   A800561         NaN  07/23/2019 08:52:00 AM  07/23/2019 08:52:00 AM
# 2   A800556         NaN  07/23/2019 07:20:00 AM  07/23/2019 07:20:00 AM
# 3   A660391         NaN  07/22/2019 06:54:00 PM  07/22/2019 06:54:00 PM
# 4   A739213       Zorro  07/22/2019 06:46:00 PM  07/22/2019 06:46:00 PM
#
#                                   Found Location    Intake Type  \
# 0                 6603 Mesa Drive in Austin (TX)          Stray
# 1               11209 Metric Blvd in Austin (TX)          Stray
# 2             4434 Frontier Trail in Austin (TX)          Stray
# 3  Pedernales And East 6Th Street in Austin (TX)          Stray
# 4                                     Manor (TX)  Public Assist
#
#   Intake Condition Animal Type_intake Sex upon Intake Age upon Intake  ...  \
# 0           Normal                Cat         Unknown         2 years  ...
# 1          Injured                Dog   Neutered Male         6 years  ...
# 2          Injured                Cat   Intact Female          1 year  ...
# 3           Normal                Dog     Intact Male         7 years  ...
# 4           Normal                Dog     Intact Male         4 years  ...
#
#   Animal Type_outcome Sex upon Outcome Age upon Outcome  Breed_outcome  \
# 0                 NaN              NaN              NaN            NaN
# 1                 NaN              NaN              NaN            NaN
# 2                 NaN              NaN              NaN            NaN
# 3                 NaN              NaN              NaN            NaN
# 4                 NaN              NaN              NaN            NaN
#
#    Color_outcome date_outcome dob age_days age_years month_outcome
# 0            NaN          NaT NaT      NaN       NaN           NaN
# 1            NaN          NaT NaT      NaN       NaN           NaN
# 2            NaN          NaT NaT      NaN       NaN           NaN
# 3            NaN          NaT NaT      NaN       NaN           NaN
# 4            NaN          NaT NaT      NaN       NaN           NaN
#
# [5 rows x 31 columns]

# %%
df['days_in_shelter'] =(df.date_outcome-df.date_income).dt.days

# %%
df['days_in_shelter']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          0.0
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18       -36.0
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
#           ...
# 119607     0.0
# 119608    10.0
# 119609     6.0
# 119610     1.0
# 119611    12.0
# 119612    47.0
# 119613     0.0
# 119614    34.0
# 119615     7.0
# 119616    13.0
# 119617    11.0
# 119618     0.0
# 119619     0.0
# 119620    18.0
# 119621    17.0
# 119622    91.0
# 119623     0.0
# 119624     0.0
# 119625     0.0
# 119626     0.0
# 119627     4.0
# 119628    23.0
# 119629     9.0
# 119630     0.0
# 119631     0.0
# 119632     0.0
# 119633     0.0
# 119634     0.0
# 119635     0.0
# 119636     0.0
# Name: days_in_shelter, Length: 119637, dtype: float64

# %%
df1 = df[(df.days_in_shelter >=0) &\
                 (animal_shelter_df.year == 2018)].\
pivot_table(values='days_in_shelter',\
            index=['Animal Type_intake', 'rounded_age'],\
           columns = 'Outcome Type')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ed7a765ad330> in <module>
# ----> 1 df1 = df[(df.days_in_shelter >=0) &\
#       2                  (animal_shelter_df.year == 2018)].\
#       3 pivot_table(values='days_in_shelter',\
#       4             index=['Animal Type_intake', 'rounded_age'],\
#       5            columns = 'Outcome Type')
#
# NameError: name 'df' is not defined
